# %%
#practice for 240822 class

# %%
import matplotlib.pyplot as plt
import numpy as np
a=np.array([2,4,6,8,10,11])
b=([3,5,7,9,11,13])
plt.xlabel('a')
plt.ylabel('b')
plt.title('line graph')
plt.plot(a,b)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
g=np.array([3,9,27,81,243,729])
h=np.array([4,16,64,256,1024,4096])
plt.title('line graph')
plt.xlabel('g')
plt.ylabel('h')
plt.plot(g,h)
plt.show()
g1=[2,4,6,8,10,12]
h1=[3,5,7,9,11,13]
plt.plot(g1,h1)
plt.show()

# %%
m=[2,3,4,5,6,7]
n=[4,5,6,7,8,9]
plt.bar(m,n)
plt.xlabel('m')
plt.ylabel('n')
plt.title('bar graph')
plt.show()

# %% [markdown]
# histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
k=np.array([9,8,7,6,5,4])
plt.hist(k,bins=[0,20,40,60,80])
plt.title('histograph plot')
plt.xlabel('k')
plt.ylabel('l')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
p=np.array([2,4,5,6,7,8,9,10,11,23,45,87,98,76,55,43,32,34,22])
plt.hist(p,bins=[5,10,15,20])
plt.title('Histograph')
plt.xlabel('bins')
plt.ylabel('frequency')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('diabities.csv')
print(df)
df.coloumns
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df)
df.coloumns

# %%
plt.hist(df['Maths'],bins=10)
plt.title('maths Histograph')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('student.csv')
print(df)

# %%
plt.hist(df['Physics'],bins=10)
plt.title('Physics histograph')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('student.csv')
print(df)

# %%
plt.boxplot(df['Maths'])

# %%
plt.hist(df['Maths'])

# %%
plt.hist(df['Chemistry'])

# %%
plt.hist(df['Physics'])
plt.xlabel('bins')
plt.ylabel('Frequency')
plt.title('Physics Histograph')

# %%
plt.hist(df['English'])
plt.xlabel('bins')
plt.ylabel('No of students')
plt.title('English histograph')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('newemplo.csv')
print(df)

# %%
plt.bar('Age','Salary')

# %%
a=np.array([23,43,55,65,76,89,45])
b=np.array([65,76,87,99,87,21,32])
plt.bar(a,b)
plt.xlabel('a')
plt.ylabel('b')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('student.csv')
print(df)

# %%
plt.violinplot(df['Biology'])
plt.show()

# %%
plt.violinplot(df['History'])
plt.show()

# %%
plt.violinplot(df['Economics'])
plt.show()

# %%
x=np.array([1,5,6,7,8,9])
y=np.array([6,5,4,3,2,1])
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('scatter plot')

# %%
a=[2,3,4,5,6,21,34]
b=[5,6,4,8,6,4,9]
plt.scatter(a,b)

# %% [raw]
# Seaborn visualaization library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
ds=pd.read_csv('emptest.csv')
print('ds')
print(ds.head())
sns.violinplot(x='Salary',data=ds)

# %%
import pandas as pd
import seaborn as sns
ds=pd.read_csv('emptest.csv')
print(ds)
sns.violinplot(x='Salary',data=ds)

# %%
dsiris=pd.read_csv('iris.csv')
print(dsiris)
print(dsiris.head())
sns.stripplot(x='class',y='sepal length',data=dsiris)

# %%
sns.swrmplot(x='class',y='sepal length',data=dsiris)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
dsiris=pd.read_csv('iris.csv')
print(dsiris)
sns.swarmplot(x='class',y='sepal length',data=dsiris)
plt.show()

# %%
dsiris['class'].value_counts()

# %%
dsiris['class'].value_counts()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv('empl.csv')
print(df)
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
sns.stripplot(y='Salary')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 sns.stripplot(y='Salary')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2807, in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2804     msg = "The `split` parameter has been renamed to `dodge`."
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
dsiris=pd.read_csv('iris.csv')
print(dsiris)
sns.swarmplot(x='class',y='sepal length',data=dsiris)
plt.show()

# %%
sns.get_dataset_names()

# %%
sns.load_dataset('planets')
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips=['tip'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 sns.distplot(tips=['tip'])
#
# TypeError: distplot() got an unexpected keyword argument 'tips'

# %%
p=int(input('enter the principal'))
r=int(input('enter the rate of interest'))
t=int(input('enter the time'))
SI=(p*r*t)/100
print("The Simple Interest is=",SI)
# Out:
# enter the principal5000
# enter the rate of interest 4
# enter the time3
# The Simple Interest is= 600.0

# %%
height=float(input("enter height in cm"))
weight=float(input("enter the weight in kg"))
BMI=weight/(height)**2
print("The BMI of the Person=",BMI)
# Out:
# enter height in cm160
# enter the weight in kg74
# The BMI of the Person= 0.002890625

# %% [raw]
# BODY MASS INDEX CALCULATOR

# %%
height=float(input("enter the height in cm"))
weight=float(input("enter the weight in kg"))
height=height/100
BMI=weight/(height)*height
print("The BMI of the person=",BMI)
if BMI>0:
    if BMI<=16:
        print("You are severely underweight")
    elif BMI<=18.5:
        print("you are the underweight")
    elif BMI<=21:
        print("you are the healthy")
    elif BMI<=23:
        print("You are overweight")
    else:
        print("You are not healthy")
else:
    print("wrong entry")
# Out:
# enter the height in cm164
# enter the weight in kg59
# The BMI of the person= 59.0
# You are not healthy

# %%
V=float(input("enter the voltage"))
I=float(input("enter the current"))
P=1.732*V*I*0.85
P=P/1000
print("The Power in system in kw is=",P)
# Out:
# enter the voltage433.3
# enter the current54.76
# The Power in system in kw is= 34.9316372776

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
